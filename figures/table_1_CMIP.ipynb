# %%
import pandas as pd
import numpy as np

# %%
names  = ['BCC_CSM2-MR', 'AWI-CM-1-0-HR', 'AWI-CM-1-0-MR', 'AWI-CM-1-0-LR', 'CanESM5', 'CNRM-CM6 HR', 'CNRM-CM6 LR',  \
          'GFDL-CM4', 'GFDL-ESM4','EMAC-2-53', 'MPI-ESM1.2-HR', 'MPI-ESM1.2-LR', 'ICON-ESM', \
          'HadGEM3-GC31-HH', 'HadGEM3-GC31-HM', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-LM', 'HadGEM3-GC31-MM']
# nominal resolution in km
a_grid = [100, 100, 100, 250,500, 100, 250, 100, 200, 500, 100, 200, 200, 50, 50, 250, 250, 100]
o_grid = [50,  25,   25, 50 ,100, 25 , 100, 25 , 100, 250, 50 , 100, 50 , 10, 25, 100, 25 , 25 ]
ratio  = np.array(a_grid, dtype=np.float)/np.array(o_grid, dtype=np.float)
# a=np.array(a_grid, dtype=np.float)
# source http://rawgit.com/WCRP-CMIP/CMIP6_CVs/master/src/CMIP6_source_id.html

# %%
df           = pd.DataFrame({ 'Name'       : names,
   ....:                      'Atmosphere' : a_grid,
   ....:                      'Ocean'      : o_grid,
   ....:                      'Ratio A/0'  : ratio**2 })

# %%
df
# Out:
#     Atmosphere             Name  Ocean  Ratio A/0
# 0          100      BCC_CSM2-MR     50       4.00
# 1          100    AWI-CM-1-0-HR     25      16.00
# 2          100    AWI-CM-1-0-MR     25      16.00
# 3          250    AWI-CM-1-0-LR     50      25.00
# 4          500          CanESM5    100      25.00
# 5          100      CNRM-CM6 HR     25      16.00
# 6          250      CNRM-CM6 LR    100       6.25
# 7          100         GFDL-CM4     25      16.00
# 8          200        GFDL-ESM4    100       4.00
# 9          500        EMAC-2-53    250       4.00
# 10         100    MPI-ESM1.2-HR     50       4.00
# 11         200    MPI-ESM1.2-LR    100       4.00
# 12         200         ICON-ESM     50      16.00
# 13          50  HadGEM3-GC31-HH     10      25.00
# 14          50  HadGEM3-GC31-HM     25       4.00
# 15         250  HadGEM3-GC31-LL    100       6.25
# 16         250  HadGEM3-GC31-LM     25     100.00
# 17         100  HadGEM3-GC31-MM     25      16.00
